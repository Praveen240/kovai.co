# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.arima.model import ARIMA
from datetime import timedelta

# %%
# Load the dataset
data = pd.read_csv(r'C:\Users\USER\OneDrive\Desktop\kovai.co\kovai.co_dataset.csv')

# Convert the 'Date' column to datetime and set it as the index
data['Date'] = pd.to_datetime(data['Date'], format='%d/%m/%Y')
data.set_index('Date', inplace=True)

# Display basic statistics and the first few rows
print("Dataset Summary:")
print(data.describe())
print("\nFirst few rows of the dataset:")
print(data.head())

# ----------------------
# Task 1: Insights
# ----------------------

# 1. Plot trends in each service type
plt.figure(figsize=(15, 10))
for i, column in enumerate(data.columns[:-1], 1):  # Exclude 'Other' column
    plt.subplot(3, 2, i)
    plt.plot(data.index, data[column], label=column, color='b')
    plt.title(f'Trend in {column}')
    plt.xlabel('Date')
    plt.ylabel('Count')
    plt.legend()
plt.tight_layout()
plt.show()

# 2. Key statistical insights
print("\nAverage ridership by service type:")
print(data.mean())

print("\nPeak ridership day for each service type:")
print(data.idxmax())

print("\nCorrelation between different service types:")
print(data.corr())

# Visualize correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(data.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation between service types")
plt.show()
# Out:
# Dataset Summary:
#         Local Route    Light Rail  Peak Service   Rapid Route       School  \
# count   1918.000000   1918.000000   1918.000000   1918.000000  1918.000000
# mean    9891.395203   7195.446298    179.581335  12597.213243  2352.694995
# std     6120.715714   3345.616428    156.532738   6720.494557  2494.766306
# min        1.000000      0.000000      0.000000      0.000000     0.000000
# 25%     3044.500000   4463.500000      0.000000   6383.000000     0.000000
# 50%    11417.000000   7507.000000    193.000000  13106.500000   567.500000
# 75%    15517.500000  10008.250000    313.750000  17924.750000  4914.000000
# max    21070.000000  15154.000000   1029.000000  28678.000000  7255.000000
#
#              Other
# count  1916.000000
# mean     42.983299
# std      41.760110
# min       0.000000
# 25%      14.000000
# 50%      39.000000
# 75%      68.000000
# max    1105.000000
#
# First few rows of the dataset:
#             Local Route  Light Rail  Peak Service  Rapid Route  School  Other
# Date
# 2019-07-01        15987        9962           407        21223    3715    NaN
# 2024-08-30        16436       10705           225        19026    3925   59.0
# 2023-09-15        15499       10671           267        18421    4519   61.0
# 2021-12-28         1756        2352             0         3775       0   13.0
# 2023-01-11        10536        8347           223        14072       0   48.0

# %%
# ----------------------
# Task 2: Forecasting
# ----------------------

# Define a function to forecast each service category for the next 7 days using ARIMA
def forecast_series(data, column_name, steps=7):
    # Fit ARIMA model
    model = ARIMA(data[column_name], order=(5,1,1))
    model_fit = model.fit()

    # Forecast the next 'steps' days
    forecast = model_fit.forecast(steps=steps)
    forecast_dates = [data.index[-1] + timedelta(days=i) for i in range(1, steps + 1)]
    
    # Plot the forecast
    plt.figure(figsize=(10, 5))
    plt.plot(data[column_name], label='Historical')
    plt.plot(forecast_dates, forecast, label='Forecast', color='red')
    plt.title(f'7-Day Forecast for {column_name}')
    plt.xlabel('Date')
    plt.ylabel('Count')
    plt.legend()
    plt.show()
    
    return forecast

# Generate and display forecasts for each required service type
forecasts = {}
forecast_df = pd.DataFrame(index=[data.index[-1] + timedelta(days=i) for i in range(1, 8)])

for column in ['Local Route', 'Light Rail', 'Peak Service', 'Rapid Route', 'School']:
    print(f"\nForecast for {column}:")
    forecasts[column] = forecast_series(data, column)
    forecast_df[column] = forecasts[column]

print("\n7-Day Forecast Data:")
print(forecast_df)
# Out:
# Forecast for Local Route:
# c:\Users\USER\anaconda3\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\USER\anaconda3\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\USER\anaconda3\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\USER\anaconda3\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\USER\anaconda3\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\USER\anaconda3\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\USER\anaconda3\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\USER\anaconda3\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# Forecast for Light Rail:
# c:\Users\USER\anaconda3\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\USER\anaconda3\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\USER\anaconda3\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\USER\anaconda3\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\USER\anaconda3\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\USER\anaconda3\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\USER\anaconda3\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\USER\anaconda3\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# Forecast for Peak Service:
# c:\Users\USER\anaconda3\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\USER\anaconda3\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\USER\anaconda3\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\USER\anaconda3\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\USER\anaconda3\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\USER\anaconda3\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\USER\anaconda3\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\USER\anaconda3\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# Forecast for Rapid Route:
# c:\Users\USER\anaconda3\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\USER\anaconda3\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\USER\anaconda3\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\USER\anaconda3\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\USER\anaconda3\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\USER\anaconda3\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\USER\anaconda3\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\USER\anaconda3\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# Forecast for School:
# c:\Users\USER\anaconda3\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\USER\anaconda3\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\USER\anaconda3\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\USER\anaconda3\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\USER\anaconda3\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\USER\anaconda3\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\USER\anaconda3\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\USER\anaconda3\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# 7-Day Forecast Data:
#             Local Route  Light Rail  Peak Service  Rapid Route  School
# 2023-07-27          NaN         NaN           NaN          NaN     NaN
# 2023-07-28          NaN         NaN           NaN          NaN     NaN
# 2023-07-29          NaN         NaN           NaN          NaN     NaN
# 2023-07-30          NaN         NaN           NaN          NaN     NaN
# 2023-07-31          NaN         NaN           NaN          NaN     NaN
# 2023-08-01          NaN         NaN           NaN          NaN     NaN
# 2023-08-02          NaN         NaN           NaN          NaN     NaN
#
# Technical Report Summary
#
# Model Choice: ARIMA (AutoRegressive Integrated Moving Average)
#
# Reasoning:
# The ARIMA model was chosen as it’s well-suited for non-seasonal, time-dependent data. This model
# is particularly effective for our dataset, as the data does not exhibit strong seasonality.
#
# Model Parameters:
# - p (Autoregressive Term): Set to 5, which means the model considers the previous 5 data points.
# - d (Differencing Term): Set to 1 to stabilize the series by removing any underlying trend.
# - q (Moving Average Term): Set to 0 as we did not prioritize error smoothing for this dataset.
#
# Limitations and Future Improvements:
# - This ARIMA model uses default parameters; tuning may improve accuracy. Alternative approaches like SARIMA
#   or Facebook Prophet could be used if seasonality is observed.
# - Forecast accuracy could be validated with Mean Absolute Error (MAE) or Root Mean Square Error (RMSE) using a train-test split.

# %%
# ----------------------
# Task 3: Technical Report Summary
# ----------------------

# Technical Overview of ARIMA
"""
Technical Report Summary
Project Title: Analyzing and Forecasting Ridership Data

Objective: The main goal of this project is to dive into historical ridership data across various service types and create forecasts for future ridership using time series analysis techniques.

1. Data Loading and Preprocessing
First, we import the dataset using pandas, specifying the path to the CSV file containing the ridership data. We convert the 'Date' column into a datetime format and set it as the index for the DataFrame. This step makes it easier to perform time series operations.

2. Data Exploration
We start exploring the dataset by displaying basic statistics with data.describe(), which gives us insights into the mean, standard deviation, minimum, and maximum values for each service type. To get a better feel for the data structure and contents, we print the first few rows of the dataset.

3. Trend Analysis
Next, we generate line plots for each service type to visualize ridership trends over time. Each subplot focuses on a different service type, allowing us to compare trends directly. These visualizations help us spot overall ridership patterns, potential seasonal effects, and peaks in demand.

4. Statistical Insights
We calculate and display the average ridership for each service type, which provides a snapshot of typical usage. We also identify the peak ridership day for each service type using the .idxmax() method. Additionally, we conduct correlation analysis to explore relationships between different service types, visualizing these correlations with a heatmap.

5. Forecasting
We define a forecasting function using the ARIMA model to predict ridership for the next seven days. The model is fitted to our data, and we generate forecasts that are plotted alongside historical data for each service type. This gives us a clear visual context for our predictions.

6. Visualization Enhancements
To deepen our understanding of trends, we consider adding more visualizations:
Rolling Average Plots: These would help smooth out short-term fluctuations and highlight longer-term trends.
Seasonal Decomposition Plots: By separating the time series into trend, seasonal, and residual components, we can clarify underlying patterns.
Area Plots: These could be useful for representing cumulative ridership trends across different service types.

"""
# Out:
# "\nTechnical Report Summary\nProject Title: Analysis and Forecasting of Ridership Data\n\nObjective: The objective of this project is to analyze historical ridership data across various service types and generate forecasts for future ridership using time series analysis techniques.\n\n1. Data Loading and Preprocessing\nThe dataset is imported using pandas, with the path specified for a CSV file containing ridership data.\nThe 'Date' column is converted to a datetime format and set as the index of the DataFrame, facilitating time series operations.\n2. Data Exploration\nBasic statistics of the dataset are displayed using data.describe(), providing insights into the mean, standard deviation, minimum, and maximum values for each service type.\nThe first few rows of the dataset are printed to give an overview of the data structure and contents.\n3. Trend Analysis\nLine Plots:\nLine plots are generated for each service type to visualize trends in ridership over time. Each subplot presents a different service type, allowing for direct comparison of trends.\nKey visualizations include overall ridership patterns, potential seasonality, and peaks in demand.\n4. Statistical Insights\nThe average ridership for each service type is calculated and displayed, providing a summary of typical usage.\nThe peak ridership day for each service type is identified using the .idxmax() method.\nCorrelation analysis is conducted to understand relationships between different service types, and a heatmap visualizes these correlations.\n5. Forecasting\nA forecasting function using the ARIMA model is defined to predict ridership for the next seven days.\nThe model is fit to the data, and forecasts are generated and plotted alongside historical data for each service type, providing visual context for the predictions.\n6. Visualization Enhancements\nAdditional plots could enhance understanding of trends:\nRolling Average Plots: To smooth short-term fluctuations and highlight longer-term trends.\nSeasonal Decomposition Plots: To separate the time series into trend, seasonal, and residual components, clarifying underlying patterns.\nArea Plots: To represent cumulative ridership trends across different service types.\n\n"
